# %%
#Source - https://www.kaggle.com/c/boston-housing

import torch
import torch.nn as nn
import numpy as np
import pandas as pd

# %%
dataset = '~/Downloads/Machine-learning/2022Practice/Boston_Housing/Boston.csv'
df = pd.read_csv(dataset)
df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
df = df.drop('Unnamed: 0', 1)
df_test = df.drop('medv', 1)
targets = df['medv']
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df_test
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
targets
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
targets.shape
# Out:
# (506,)

# %%
train_inputs = df_test.iloc[:400]
target_inputs = df_test.iloc[400:]
train_outputs = targets.iloc[:400]
target_outputs = targets.iloc[400:]

# %%
train_inputs = torch.Tensor(train_inputs.values)
target_inputs = torch.Tensor(target_inputs.values)
train_outputs = torch.Tensor(train_outputs.values)
target_outputs = torch.Tensor(target_outputs.values)

# %%
target_outputs
# Out:
# tensor([ 5.6000,  7.2000, 12.1000,  8.3000,  8.5000,  5.0000, 11.9000, 27.9000,
#         17.2000, 27.5000, 15.0000, 17.2000, 17.9000, 16.3000,  7.0000,  7.2000,
#          7.5000, 10.4000,  8.8000,  8.4000, 16.7000, 14.2000, 20.8000, 13.4000,
#         11.7000,  8.3000, 10.2000, 10.9000, 11.0000,  9.5000, 14.5000, 14.1000,
#         16.1000, 14.3000, 11.7000, 13.4000,  9.6000,  8.7000,  8.4000, 12.8000,
#         10.5000, 17.1000, 18.4000, 15.4000, 10.8000, 11.8000, 14.9000, 12.6000,
#         14.1000, 13.0000, 13.4000, 15.2000, 16.1000, 17.8000, 14.9000, 14.1000,
#         12.7000, 13.5000, 14.9000, 20.0000, 16.4000, 17.7000, 19.5000, 20.2000,
#         21.4000, 19.9000, 19.0000, 19.1000, 19.1000, 20.1000, 19.9000, 19.6000,
#         23.2000, 29.8000, 13.8000, 13.3000, 16.7000, 12.0000, 14.6000, 21.4000,
#         23.0000, 23.7000, 25.0000, 21.8000, 20.6000, 21.2000, 19.1000, 20.6000,
#         15.2000,  7.0000,  8.1000, 13.6000, 20.1000, 21.8000, 24.5000, 23.1000,
#         19.7000, 18.3000, 21.2000, 17.5000, 16.8000, 22.4000, 20.6000, 23.9000,
#         22.0000, 11.9000])

# %%
#Define and setup the dataset using pytorch inbuilt functions

from torch.utils.data import TensorDataset

train_ds = TensorDataset(train_inputs, train_outputs)

#print(train_ds[0:3])

# %%
print(train_inputs.shape)
print(target_inputs.shape)
print(train_outputs.shape)
print(target_outputs.shape)
# Out:
# torch.Size([400, 13])
# torch.Size([106, 13])
# torch.Size([400])
# torch.Size([106])

# %%
#Define and setup the DataLoader

from torch.utils.data import DataLoader

batch_size = 5
train_dl = DataLoader(train_ds, batch_size, shuffle = True)

for xb,yb in train_dl:
    print(xb)
    print(yb)
    break
# Out:
# tensor([[3.5780e-02, 2.0000e+01, 3.3300e+00, 0.0000e+00, 4.4290e-01, 7.8200e+00,
#          6.4500e+01, 4.6947e+00, 5.0000e+00, 2.1600e+02, 1.4900e+01, 3.8731e+02,
#          3.7600e+00],
#         [1.3110e-02, 9.0000e+01, 1.2200e+00, 0.0000e+00, 4.0300e-01, 7.2490e+00,
#          2.1900e+01, 8.6966e+00, 5.0000e+00, 2.2600e+02, 1.7900e+01, 3.9593e+02,
#          4.8100e+00],
#         [1.3117e-01, 0.0000e+00, 8.5600e+00, 0.0000e+00, 5.2000e-01, 6.1270e+00,
#          8.5200e+01, 2.1224e+00, 5.0000e+00, 3.8400e+02, 2.0900e+01, 3.8769e+02,
#          1.4090e+01],
#         [8.0271e-01, 0.0000e+00, 8.1400e+00, 0.0000e+00, 5.3800e-01, 5.4560e+00,
#          3.6600e+01, 3.7965e+00, 4.0000e+00, 3.0700e+02, 2.1000e+01, 2.8899e+02,
#          1.1690e+01],
#         [1.9657e-01, 2.2000e+01, 5.8600e+00, 0.0000e+00, 4.3100e-01, 6.2260e+00,
#          7.9200e+01, 8.0555e+00, 7.0000e+00, 3.3000e+02, 1.9100e+01, 3.7614e+02,
#          1.0150e+01]])
# tensor([45.4000, 35.4000, 20.4000, 20.2000, 20.5000])

# %%
class SimpleNet(nn.Module):
    def __init__(self):
        super(SimpleNet, self).__init__()
        self.linear1 = nn.Linear(13,50)
        self.act1 = nn.ReLU()
        self.linear2 = nn.Linear(50,10)
        self.act2 = nn.ReLU()
        self.Linear3 = nn.Linear(10,1)
        
    def forward(self, x):
        x = self.linear1(x)
        x = self.act1(x)
        x = self.linear2(x)
        x = self.act2(x)
        x = self.Linear3(x)
        return x

# %%
model = SimpleNet()
opt = torch.optim.SGD(model.parameters(), lr = 1e-5)
loss_fn = F.mse_loss

# %%
#Define Optimizer/Algorithm - SGD (GD) & Train the model

opt = torch.optim.SGD(model.parameters(), lr=1e-5)

def Fit(num_epochs, model, loss_fn, opt, train_dl):
    
    for epoch in range(num_epochs):
        
        for xb,yb in train_dl:
            
            pred = model(xb)
            loss = loss_fn(pred, yb)
            loss.backward()
            opt.step()
            opt.zero_grad()
        
        if (epoch+1) % 10 ==0:
            print('Epoch [{}/{}], Loss: {:.4f}'.format(epoch+1, num_epochs, loss.item()))

# %%
Fit(200, model, loss_fn, opt, train_dl)
# Out:
# <ipython-input-117-e0efd1cf4564>:12: UserWarning: Using a target size (torch.Size([5])) that is different to the input size (torch.Size([5, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   loss = loss_fn(pred, yb)
# Epoch [10/200], Loss: 78.7940
# Epoch [20/200], Loss: 4.9170
# Epoch [30/200], Loss: 10.7810
# Epoch [40/200], Loss: 79.9231
# Epoch [50/200], Loss: 309.8735
# Epoch [60/200], Loss: 84.6071
# Epoch [70/200], Loss: 39.1423
# Epoch [80/200], Loss: 29.9465
# Epoch [90/200], Loss: 211.9306
# Epoch [100/200], Loss: 41.2395
# Epoch [110/200], Loss: 32.8666
# Epoch [120/200], Loss: 50.0736
# Epoch [130/200], Loss: 184.0829
# Epoch [140/200], Loss: 208.0692
# Epoch [150/200], Loss: 155.9028
# Epoch [160/200], Loss: 240.8629
# Epoch [170/200], Loss: 74.7511
# Epoch [180/200], Loss: 48.1716
# Epoch [190/200], Loss: 91.6381
# Epoch [200/200], Loss: 8.0562

# %%
print("targets are",target_outputs)
print("predictions are", model(target_inputs))
# Out:
# targets are tensor([ 5.6000,  7.2000, 12.1000,  8.3000,  8.5000,  5.0000, 11.9000, 27.9000,
#         17.2000, 27.5000, 15.0000, 17.2000, 17.9000, 16.3000,  7.0000,  7.2000,
#          7.5000, 10.4000,  8.8000,  8.4000, 16.7000, 14.2000, 20.8000, 13.4000,
#         11.7000,  8.3000, 10.2000, 10.9000, 11.0000,  9.5000, 14.5000, 14.1000,
#         16.1000, 14.3000, 11.7000, 13.4000,  9.6000,  8.7000,  8.4000, 12.8000,
#         10.5000, 17.1000, 18.4000, 15.4000, 10.8000, 11.8000, 14.9000, 12.6000,
#         14.1000, 13.0000, 13.4000, 15.2000, 16.1000, 17.8000, 14.9000, 14.1000,
#         12.7000, 13.5000, 14.9000, 20.0000, 16.4000, 17.7000, 19.5000, 20.2000,
#         21.4000, 19.9000, 19.0000, 19.1000, 19.1000, 20.1000, 19.9000, 19.6000,
#         23.2000, 29.8000, 13.8000, 13.3000, 16.7000, 12.0000, 14.6000, 21.4000,
#         23.0000, 23.7000, 25.0000, 21.8000, 20.6000, 21.2000, 19.1000, 20.6000,
#         15.2000,  7.0000,  8.1000, 13.6000, 20.1000, 21.8000, 24.5000, 23.1000,
#         19.7000, 18.3000, 21.2000, 17.5000, 16.8000, 22.4000, 20.6000, 23.9000,
#         22.0000, 11.9000])
# predictions are tensor([[24.2421],
#         [24.6879],
#         [25.1809],
#         [24.2358],
#         [24.0419],
#         [23.7968],
#         [24.8392],
#         [26.1623],
#         [26.2253],
#         [30.1591],
#         [35.1082],
#         [34.6598],
#         [34.3964],
#         [28.8116],
#         [32.1497],
#         [34.5972],
#         [34.3748],
#         [30.7354],
#         [33.9763],
#         [32.7851],
#         [26.3788],
#         [26.1626],
#         [26.2468],
#         [34.8175],
#         [34.0447],
#         [34.9819],
#         [32.6138],
#         [33.4546],
#         [31.6080],
#         [33.6656],
#         [32.6112],
#         [33.1072],
#         [31.5827],
#         [32.2540],
#         [32.5229],
#         [32.0974],
#         [34.5003],
#         [35.2074],
#         [32.5763],
#         [24.2912],
#         [23.8650],
#         [24.7957],
#         [25.0646],
#         [24.9862],
#         [28.0276],
#         [34.0731],
#         [26.2530],
#         [24.7721],
#         [24.7968],
#         [26.6298],
#         [35.4201],
#         [25.6634],
#         [24.6455],
#         [25.2780],
#         [35.2077],
#         [33.6008],
#         [34.7878],
#         [34.5850],
#         [26.5443],
#         [24.1340],
#         [27.4635],
#         [24.3903],
#         [24.1052],
#         [24.6648],
#         [23.3810],
#         [23.2247],
#         [34.3274],
#         [25.7962],
#         [23.2085],
#         [22.8124],
#         [24.1329],
#         [24.5933],
#         [23.8143],
#         [23.5167],
#         [25.4203],
#         [26.5427],
#         [24.5421],
#         [25.2320],
#         [24.9089],
#         [24.2167],
#         [23.5134],
#         [24.0442],
#         [24.2137],
#         [22.6765],
#         [22.4795],
#         [23.0114],
#         [23.9035],
#         [23.0126],
#         [28.0575],
#         [29.2243],
#         [29.6811],
#         [28.5705],
#         [27.4760],
#         [25.5014],
#         [25.2288],
#         [24.5018],
#         [25.0596],
#         [25.5648],
#         [25.5852],
#         [25.4563],
#         [25.6719],
#         [25.7326],
#         [26.2454],
#         [26.7471],
#         [26.4057],
#         [26.4064]], grad_fn=<AddmmBackward0>)
