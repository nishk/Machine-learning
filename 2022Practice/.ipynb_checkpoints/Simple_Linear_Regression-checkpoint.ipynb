# %%
import numpy as np
import matplotlib.pyplot as plt
import math
# %precision %.2f
# Out:
# '%.2f'

# %%
x = [1.0, 2.0, 3.0]
y = [4.0, 6.0, 9.0]
#x.astype('float64')
#y.astype('float64')

w_list=[]
loss_list=[]
w = 0.0

def forward(x):
    return w*x

def loss(x,y):
    y_pred = forward(x)
    return(y - y_pred)*(y - y_pred)

for w in np.arange(0.0, 4.0, 0.1):
    print("w=",round(w,2))
    l_sum = 0
    for x_val, y_val in zip (x,y):
        y_pred = forward(x_val)
        l = loss(x_val,y_val)
        l_sum += l
        print("\t", round(x_val,2), round(y_val,2),round(y_pred,2), round(MSE,2))
    print("MSE is: ", round(l_sum/3,2))
    w_list.append(w)
    loss_list.append(l_sum/3)

print('minimum loss is: ', min(loss_list))
print('Corresponding w is: ',w_list[loss_list.index(min(loss_list))])

w_min = w_list[loss_list.index(min(loss_list))]
y_pred = w_min*np.asarray(x)

f1 = plt.figure(1)
plt.plot(w_list,loss_list)
plt.ylabel('Loss')
plt.xlabel('w')

f2 = plt.figure(2)
plt.plot(x, y, label='Actual Values', color='Red')
plt.plot(x, y_pred, label='Predicted Values', color='Green')
plt.xlabel('hours')
plt.ylabel('Marks')
plt.legend()
# Out:
# w= 0.0
# 	 1.0 3.0 0.0 22.09
# 	 2.0 5.0 0.0 22.09
# 	 3.0 7.0 0.0 22.09
# MSE is:  27.67
# w= 0.1
# 	 1.0 3.0 0.1 22.09
# 	 2.0 5.0 0.2 22.09
# 	 3.0 7.0 0.3 22.09
# MSE is:  25.45
# w= 0.2
# 	 1.0 3.0 0.2 22.09
# 	 2.0 5.0 0.4 22.09
# 	 3.0 7.0 0.6 22.09
# MSE is:  23.32
# w= 0.3
# 	 1.0 3.0 0.3 22.09
# 	 2.0 5.0 0.6 22.09
# 	 3.0 7.0 0.9 22.09
# MSE is:  21.29
# w= 0.4
# 	 1.0 3.0 0.4 22.09
# 	 2.0 5.0 0.8 22.09
# 	 3.0 7.0 1.2 22.09
# MSE is:  19.35
# w= 0.5
# 	 1.0 3.0 0.5 22.09
# 	 2.0 5.0 1.0 22.09
# 	 3.0 7.0 1.5 22.09
# MSE is:  17.5
# w= 0.6
# 	 1.0 3.0 0.6 22.09
# 	 2.0 5.0 1.2 22.09
# 	 3.0 7.0 1.8 22.09
# MSE is:  15.75
# w= 0.7
# 	 1.0 3.0 0.7 22.09
# 	 2.0 5.0 1.4 22.09
# 	 3.0 7.0 2.1 22.09
# MSE is:  14.09
# w= 0.8
# 	 1.0 3.0 0.8 22.09
# 	 2.0 5.0 1.6 22.09
# 	 3.0 7.0 2.4 22.09
# MSE is:  12.52
# w= 0.9
# 	 1.0 3.0 0.9 22.09
# 	 2.0 5.0 1.8 22.09
# 	 3.0 7.0 2.7 22.09
# MSE is:  11.05
# w= 1.0
# 	 1.0 3.0 1.0 22.09
# 	 2.0 5.0 2.0 22.09
# 	 3.0 7.0 3.0 22.09
# MSE is:  9.67
# w= 1.1
# 	 1.0 3.0 1.1 22.09
# 	 2.0 5.0 2.2 22.09
# 	 3.0 7.0 3.3 22.09
# MSE is:  8.38
# w= 1.2
# 	 1.0 3.0 1.2 22.09
# 	 2.0 5.0 2.4 22.09
# 	 3.0 7.0 3.6 22.09
# MSE is:  7.19
# w= 1.3
# 	 1.0 3.0 1.3 22.09
# 	 2.0 5.0 2.6 22.09
# 	 3.0 7.0 3.9 22.09
# MSE is:  6.09
# w= 1.4
# 	 1.0 3.0 1.4 22.09
# 	 2.0 5.0 2.8 22.09
# 	 3.0 7.0 4.2 22.09
# MSE is:  5.08
# w= 1.5
# 	 1.0 3.0 1.5 22.09
# 	 2.0 5.0 3.0 22.09
# 	 3.0 7.0 4.5 22.09
# MSE is:  4.17
# w= 1.6
# 	 1.0 3.0 1.6 22.09
# 	 2.0 5.0 3.2 22.09
# 	 3.0 7.0 4.8 22.09
# MSE is:  3.35
# w= 1.7
# 	 1.0 3.0 1.7 22.09
# 	 2.0 5.0 3.4 22.09
# 	 3.0 7.0 5.1 22.09
# MSE is:  2.62
# w= 1.8
# 	 1.0 3.0 1.8 22.09
# 	 2.0 5.0 3.6 22.09
# 	 3.0 7.0 5.4 22.09
# MSE is:  1.99
# w= 1.9
# 	 1.0 3.0 1.9 22.09
# 	 2.0 5.0 3.8 22.09
# 	 3.0 7.0 5.7 22.09
# MSE is:  1.45
# w= 2.0
# 	 1.0 3.0 2.0 22.09
# 	 2.0 5.0 4.0 22.09
# 	 3.0 7.0 6.0 22.09
# MSE is:  1.0
# w= 2.1
# 	 1.0 3.0 2.1 22.09
# 	 2.0 5.0 4.2 22.09
# 	 3.0 7.0 6.3 22.09
# MSE is:  0.65
# w= 2.2
# 	 1.0 3.0 2.2 22.09
# 	 2.0 5.0 4.4 22.09
# 	 3.0 7.0 6.6 22.09
# MSE is:  0.39
# w= 2.3
# 	 1.0 3.0 2.3 22.09
# 	 2.0 5.0 4.6 22.09
# 	 3.0 7.0 6.9 22.09
# MSE is:  0.22
# w= 2.4
# 	 1.0 3.0 2.4 22.09
# 	 2.0 5.0 4.8 22.09
# 	 3.0 7.0 7.2 22.09
# MSE is:  0.15
# w= 2.5
# 	 1.0 3.0 2.5 22.09
# 	 2.0 5.0 5.0 22.09
# 	 3.0 7.0 7.5 22.09
# MSE is:  0.17
# w= 2.6
# 	 1.0 3.0 2.6 22.09
# 	 2.0 5.0 5.2 22.09
# 	 3.0 7.0 7.8 22.09
# MSE is:  0.28
# w= 2.7
# 	 1.0 3.0 2.7 22.09
# 	 2.0 5.0 5.4 22.09
# 	 3.0 7.0 8.1 22.09
# MSE is:  0.49
# w= 2.8
# 	 1.0 3.0 2.8 22.09
# 	 2.0 5.0 5.6 22.09
# 	 3.0 7.0 8.4 22.09
# MSE is:  0.79
# w= 2.9
# 	 1.0 3.0 2.9 22.09
# 	 2.0 5.0 5.8 22.09
# 	 3.0 7.0 8.7 22.09
# MSE is:  1.18
# w= 3.0
# 	 1.0 3.0 3.0 22.09
# 	 2.0 5.0 6.0 22.09
# 	 3.0 7.0 9.0 22.09
# MSE is:  1.67
# w= 3.1
# 	 1.0 3.0 3.1 22.09
# 	 2.0 5.0 6.2 22.09
# 	 3.0 7.0 9.3 22.09
# MSE is:  2.25
# w= 3.2
# 	 1.0 3.0 3.2 22.09
# 	 2.0 5.0 6.4 22.09
# 	 3.0 7.0 9.6 22.09
# MSE is:  2.92
# w= 3.3
# 	 1.0 3.0 3.3 22.09
# 	 2.0 5.0 6.6 22.09
# 	 3.0 7.0 9.9 22.09
# MSE is:  3.69
# w= 3.4
# 	 1.0 3.0 3.4 22.09
# 	 2.0 5.0 6.8 22.09
# 	 3.0 7.0 10.2 22.09
# MSE is:  4.55
# w= 3.5
# 	 1.0 3.0 3.5 22.09
# 	 2.0 5.0 7.0 22.09
# 	 3.0 7.0 10.5 22.09
# MSE is:  5.5
# w= 3.6
# 	 1.0 3.0 3.6 22.09
# 	 2.0 5.0 7.2 22.09
# 	 3.0 7.0 10.8 22.09
# MSE is:  6.55
# w= 3.7
# 	 1.0 3.0 3.7 22.09
# 	 2.0 5.0 7.4 22.09
# 	 3.0 7.0 11.1 22.09
# MSE is:  7.69
# w= 3.8
# 	 1.0 3.0 3.8 22.09
# 	 2.0 5.0 7.6 22.09
# 	 3.0 7.0 11.4 22.09
# MSE is:  8.92
# w= 3.9
# 	 1.0 3.0 3.9 22.09
# 	 2.0 5.0 7.8 22.09
# 	 3.0 7.0 11.7 22.09
# MSE is:  10.25
# minimum loss is:  0.14666666666666658
# Corresponding w is:  2.4000000000000004
