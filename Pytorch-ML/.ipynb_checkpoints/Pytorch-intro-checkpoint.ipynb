# %%
#Simple Univariate Linear regression

import torch
import numpy as np
import matplotlib.pyplot as plt

x_data = [1.0,2.0,3.0,4.0]
y_data = [6.0,7.0,8.0,9.0]
m = len(y_data)
w = 1
w_list = []
mse_list = []

#Forward function for our model -> y = w*x 
def forward(x):
    return w*x

#Loss Function
def loss(x,y):
    y_pred = forward(x)
    return (y_pred -y)**2

for w in np.arange(0.0, 8.1, 0.2):
    print("w=",w)
    l_sum=0
    for x_val, y_val in zip(x_data,y_data):
        y_pred_val = forward(x_val)
        l = loss(x_val,y_val)
        l_sum += l
        print("\t", x_val, y_val, y_pred_val, l)
    print("MSE=", l_sum/m)
    w_list.append(w)
    mse_list.append(l_sum/m)
plt.plot(w_list,mse_list)
plt.ylabel('Loss')
plt.xlabel('w')
plt.show();
#min_w = min(w_list)
#print (min_w)
index_min_mse = mse_list.index(min(mse_list)) 
print ("Min error is:",mse_list.pop(index_min_mse))
print ("The corresponding w is:",w_list.pop(index_min_mse))

y_model_pred = w_list.pop(index_min_mse)*np.asarray(x_data)
#print(y_model_pred, y_data)

plt.plot(x_data,y_data, label='Actual_model',color='red')
plt.plot(x_data,y_model_pred,color='green', label='Predicted model')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show();
# Out:
# w= 0.0
# 	 1.0 6.0 0.0 36.0
# 	 2.0 7.0 0.0 49.0
# 	 3.0 8.0 0.0 64.0
# 	 4.0 9.0 0.0 81.0
# MSE= 57.5
# w= 0.2
# 	 1.0 6.0 0.2 33.64
# 	 2.0 7.0 0.4 43.559999999999995
# 	 3.0 8.0 0.6000000000000001 54.760000000000005
# 	 4.0 9.0 0.8 67.24
# MSE= 49.8
# w= 0.4
# 	 1.0 6.0 0.4 31.359999999999996
# 	 2.0 7.0 0.8 38.440000000000005
# 	 3.0 8.0 1.2000000000000002 46.239999999999995
# 	 4.0 9.0 1.6 54.760000000000005
# MSE= 42.7
# w= 0.6000000000000001
# 	 1.0 6.0 0.6000000000000001 29.160000000000004
# 	 2.0 7.0 1.2000000000000002 33.64
# 	 3.0 8.0 1.8000000000000003 38.43999999999999
# 	 4.0 9.0 2.4000000000000004 43.559999999999995
# MSE= 36.199999999999996
# w= 0.8
# 	 1.0 6.0 0.8 27.040000000000003
# 	 2.0 7.0 1.6 29.160000000000004
# 	 3.0 8.0 2.4000000000000004 31.359999999999996
# 	 4.0 9.0 3.2 33.64
# MSE= 30.3
# w= 1.0
# 	 1.0 6.0 1.0 25.0
# 	 2.0 7.0 2.0 25.0
# 	 3.0 8.0 3.0 25.0
# 	 4.0 9.0 4.0 25.0
# MSE= 25.0
# w= 1.2000000000000002
# 	 1.0 6.0 1.2000000000000002 23.04
# 	 2.0 7.0 2.4000000000000004 21.159999999999997
# 	 3.0 8.0 3.6000000000000005 19.359999999999996
# 	 4.0 9.0 4.800000000000001 17.639999999999993
# MSE= 20.299999999999997
# w= 1.4000000000000001
# 	 1.0 6.0 1.4000000000000001 21.159999999999997
# 	 2.0 7.0 2.8000000000000003 17.639999999999993
# 	 3.0 8.0 4.2 14.44
# 	 4.0 9.0 5.6000000000000005 11.559999999999997
# MSE= 16.199999999999996
# w= 1.6
# 	 1.0 6.0 1.6 19.360000000000003
# 	 2.0 7.0 3.2 14.44
# 	 3.0 8.0 4.800000000000001 10.239999999999995
# 	 4.0 9.0 6.4 6.759999999999998
# MSE= 12.7
# w= 1.8
# 	 1.0 6.0 1.8 17.64
# 	 2.0 7.0 3.6 11.559999999999999
# 	 3.0 8.0 5.4 6.759999999999998
# 	 4.0 9.0 7.2 3.2399999999999993
# MSE= 9.799999999999999
# w= 2.0
# 	 1.0 6.0 2.0 16.0
# 	 2.0 7.0 4.0 9.0
# 	 3.0 8.0 6.0 4.0
# 	 4.0 9.0 8.0 1.0
# MSE= 7.5
# w= 2.2
# 	 1.0 6.0 2.2 14.44
# 	 2.0 7.0 4.4 6.759999999999998
# 	 3.0 8.0 6.6000000000000005 1.9599999999999984
# 	 4.0 9.0 8.8 0.039999999999999716
# MSE= 5.799999999999998
# w= 2.4000000000000004
# 	 1.0 6.0 2.4000000000000004 12.959999999999997
# 	 2.0 7.0 4.800000000000001 4.839999999999997
# 	 3.0 8.0 7.200000000000001 0.6399999999999983
# 	 4.0 9.0 9.600000000000001 0.3600000000000017
# MSE= 4.699999999999998
# w= 2.6
# 	 1.0 6.0 2.6 11.559999999999999
# 	 2.0 7.0 5.2 3.2399999999999993
# 	 3.0 8.0 7.800000000000001 0.039999999999999716
# 	 4.0 9.0 10.4 1.960000000000001
# MSE= 4.199999999999999
# w= 2.8000000000000003
# 	 1.0 6.0 2.8000000000000003 10.239999999999998
# 	 2.0 7.0 5.6000000000000005 1.9599999999999984
# 	 3.0 8.0 8.4 0.16000000000000028
# 	 4.0 9.0 11.200000000000001 4.840000000000004
# MSE= 4.300000000000001
# w= 3.0
# 	 1.0 6.0 3.0 9.0
# 	 2.0 7.0 6.0 1.0
# 	 3.0 8.0 9.0 1.0
# 	 4.0 9.0 12.0 9.0
# MSE= 5.0
# w= 3.2
# 	 1.0 6.0 3.2 7.839999999999999
# 	 2.0 7.0 6.4 0.3599999999999996
# 	 3.0 8.0 9.600000000000001 2.5600000000000045
# 	 4.0 9.0 12.8 14.440000000000005
# MSE= 6.3000000000000025
# w= 3.4000000000000004
# 	 1.0 6.0 3.4000000000000004 6.759999999999998
# 	 2.0 7.0 6.800000000000001 0.039999999999999716
# 	 3.0 8.0 10.200000000000001 4.840000000000004
# 	 4.0 9.0 13.600000000000001 21.160000000000014
# MSE= 8.200000000000005
# w= 3.6
# 	 1.0 6.0 3.6 5.76
# 	 2.0 7.0 7.2 0.04000000000000007
# 	 3.0 8.0 10.8 7.840000000000004
# 	 4.0 9.0 14.4 29.160000000000004
# MSE= 10.700000000000003
# w= 3.8000000000000003
# 	 1.0 6.0 3.8000000000000003 4.839999999999999
# 	 2.0 7.0 7.6000000000000005 0.36000000000000065
# 	 3.0 8.0 11.4 11.560000000000002
# 	 4.0 9.0 15.200000000000001 38.44000000000001
# MSE= 13.800000000000004
# w= 4.0
# 	 1.0 6.0 4.0 4.0
# 	 2.0 7.0 8.0 1.0
# 	 3.0 8.0 12.0 16.0
# 	 4.0 9.0 16.0 49.0
# MSE= 17.5
# w= 4.2
# 	 1.0 6.0 4.2 3.2399999999999993
# 	 2.0 7.0 8.4 1.960000000000001
# 	 3.0 8.0 12.600000000000001 21.160000000000014
# 	 4.0 9.0 16.8 60.84000000000001
# MSE= 21.800000000000004
# w= 4.4
# 	 1.0 6.0 4.4 2.5599999999999987
# 	 2.0 7.0 8.8 3.2400000000000024
# 	 3.0 8.0 13.200000000000001 27.04000000000001
# 	 4.0 9.0 17.6 73.96000000000002
# MSE= 26.70000000000001
# w= 4.6000000000000005
# 	 1.0 6.0 4.6000000000000005 1.9599999999999984
# 	 2.0 7.0 9.200000000000001 4.840000000000004
# 	 3.0 8.0 13.8 33.64000000000001
# 	 4.0 9.0 18.400000000000002 88.36000000000004
# MSE= 32.20000000000002
# w= 4.800000000000001
# 	 1.0 6.0 4.800000000000001 1.4399999999999984
# 	 2.0 7.0 9.600000000000001 6.760000000000008
# 	 3.0 8.0 14.400000000000002 40.96000000000003
# 	 4.0 9.0 19.200000000000003 104.04000000000006
# MSE= 38.300000000000026
# w= 5.0
# 	 1.0 6.0 5.0 1.0
# 	 2.0 7.0 10.0 9.0
# 	 3.0 8.0 15.0 49.0
# 	 4.0 9.0 20.0 121.0
# MSE= 45.0
# w= 5.2
# 	 1.0 6.0 5.2 0.6399999999999997
# 	 2.0 7.0 10.4 11.560000000000002
# 	 3.0 8.0 15.600000000000001 57.76000000000002
# 	 4.0 9.0 20.8 139.24
# MSE= 52.30000000000001
# w= 5.4
# 	 1.0 6.0 5.4 0.3599999999999996
# 	 2.0 7.0 10.8 14.440000000000005
# 	 3.0 8.0 16.200000000000003 67.24000000000005
# 	 4.0 9.0 21.6 158.76000000000005
# MSE= 60.200000000000024
# w= 5.6000000000000005
# 	 1.0 6.0 5.6000000000000005 0.1599999999999996
# 	 2.0 7.0 11.200000000000001 17.640000000000008
# 	 3.0 8.0 16.8 77.44000000000001
# 	 4.0 9.0 22.400000000000002 179.56000000000006
# MSE= 68.70000000000002
# w= 5.800000000000001
# 	 1.0 6.0 5.800000000000001 0.039999999999999716
# 	 2.0 7.0 11.600000000000001 21.160000000000014
# 	 3.0 8.0 17.400000000000002 88.36000000000004
# 	 4.0 9.0 23.200000000000003 201.64000000000007
# MSE= 77.80000000000004
# w= 6.0
# 	 1.0 6.0 6.0 0.0
# 	 2.0 7.0 12.0 25.0
# 	 3.0 8.0 18.0 100.0
# 	 4.0 9.0 24.0 225.0
# MSE= 87.5
# w= 6.2
# 	 1.0 6.0 6.2 0.04000000000000007
# 	 2.0 7.0 12.4 29.160000000000004
# 	 3.0 8.0 18.6 112.36000000000003
# 	 4.0 9.0 24.8 249.64000000000001
# MSE= 97.80000000000001
# w= 6.4
# 	 1.0 6.0 6.4 0.16000000000000028
# 	 2.0 7.0 12.8 33.64000000000001
# 	 3.0 8.0 19.200000000000003 125.44000000000007
# 	 4.0 9.0 25.6 275.56000000000006
# MSE= 108.70000000000003
# w= 6.6000000000000005
# 	 1.0 6.0 6.6000000000000005 0.36000000000000065
# 	 2.0 7.0 13.200000000000001 38.44000000000001
# 	 3.0 8.0 19.8 139.24
# 	 4.0 9.0 26.400000000000002 302.76000000000005
# MSE= 120.20000000000002
# w= 6.800000000000001
# 	 1.0 6.0 6.800000000000001 0.6400000000000011
# 	 2.0 7.0 13.600000000000001 43.56000000000002
# 	 3.0 8.0 20.400000000000002 153.76000000000005
# 	 4.0 9.0 27.200000000000003 331.2400000000001
# MSE= 132.30000000000004
# w= 7.0
# 	 1.0 6.0 7.0 1.0
# 	 2.0 7.0 14.0 49.0
# 	 3.0 8.0 21.0 169.0
# 	 4.0 9.0 28.0 361.0
# MSE= 145.0
# w= 7.2
# 	 1.0 6.0 7.2 1.4400000000000004
# 	 2.0 7.0 14.4 54.760000000000005
# 	 3.0 8.0 21.6 184.96000000000004
# 	 4.0 9.0 28.8 392.04
# MSE= 158.3
# w= 7.4
# 	 1.0 6.0 7.4 1.960000000000001
# 	 2.0 7.0 14.8 60.84000000000001
# 	 3.0 8.0 22.200000000000003 201.64000000000007
# 	 4.0 9.0 29.6 424.36000000000007
# MSE= 172.20000000000005
# w= 7.6000000000000005
# 	 1.0 6.0 7.6000000000000005 2.560000000000002
# 	 2.0 7.0 15.200000000000001 67.24000000000002
# 	 3.0 8.0 22.8 219.04000000000002
# 	 4.0 9.0 30.400000000000002 457.9600000000001
# MSE= 186.70000000000005
# w= 7.800000000000001
# 	 1.0 6.0 7.800000000000001 3.2400000000000024
# 	 2.0 7.0 15.600000000000001 73.96000000000002
# 	 3.0 8.0 23.400000000000002 237.16000000000005
# 	 4.0 9.0 31.200000000000003 492.84000000000015
# MSE= 201.80000000000007
# w= 8.0
# 	 1.0 6.0 8.0 4.0
# 	 2.0 7.0 16.0 81.0
# 	 3.0 8.0 24.0 256.0
# 	 4.0 9.0 32.0 529.0
# MSE= 217.5
# Min error is: 4.199999999999999
# The corresponding w is: 2.6
# [ 2.8  5.6  8.4 11.2] [6.0, 7.0, 8.0, 9.0]
